# %%
import pandas

# %%
pandas.__version__
# Out:
# '1.2.3'

# %%
import pandas as pd

# %%
data1 = [10,20,30,40,50]
data1
# Out:
# [10, 20, 30, 40, 50]

# %%
data2 = ['1반', '2반', '3반', '4반', '5반']
data2
# Out:
# ['1반', '2반', '3반', '4반', '5반']

# %%
sr1 = pd.Series(data1)
sr1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
sr2 = pd.Series(data2)
sr2
# Out:
# 0    1반
# 1    2반
# 2    3반
# 3    4반
# 4    5반
# dtype: object

# %%
sr3 = pd.Series([101, 102, 103, 104, 105])
sr3
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# dtype: int64

# %%
sr4 = pd.Series(['월', '화', '수', '목', '금'])
sr4
# Out:
# 0    월
# 1    화
# 2    수
# 3    목
# 4    금
# dtype: object

# %%
sr5 = pd.Series(data1, index=[1000, 1001, 1002, 1003, 1004])
sr5
# Out:
# 1000    10
# 1001    20
# 1002    30
# 1003    40
# 1004    50
# dtype: int64

# %%
sr6 = pd.Series(data1, index=data2)
sr6
# Out:
# 1반    10
# 2반    20
# 3반    30
# 4반    40
# 5반    50
# dtype: int64

# %%
sr7 = pd.Series(data2, index=[10,20,30,40,50])
sr7
# Out:
# 10    1반
# 20    2반
# 30    3반
# 40    4반
# 50    5반
# dtype: object

# %%
sr8 = pd.Series(data2, index=['월', '화', '수', '목', '금'])
sr8
# Out:
# 월    1반
# 화    2반
# 수    3반
# 목    4반
# 금    5반
# dtype: object

# %%
print(sr8[2])
print(sr8['수'])
print(sr8[-1])
# Out:
# 3반
# 3반
# 5반

# %%
sr8[0:4]
# Out:
# 월    1반
# 화    2반
# 수    3반
# 목    4반
# dtype: object

# %%
sr8.index
# Out:
# Index(['월', '화', '수', '목', '금'], dtype='object')

# %%
sr8.values
# Out:
# array(['1반', '2반', '3반', '4반', '5반'], dtype=object)

# %%
print(sr1)
print(sr3)
print(sr1 + sr3)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# dtype: int64
# 0    111
# 1    122
# 2    133
# 3    144
# 4    155
# dtype: int64

# %%
print(sr2)
print(sr4)
print(sr4 + sr2)
# Out:
# 0    1반
# 1    2반
# 2    3반
# 3    4반
# 4    5반
# dtype: object
# 0    월
# 1    화
# 2    수
# 3    목
# 4    금
# dtype: object
# 0    월1반
# 1    화2반
# 2    수3반
# 3    목4반
# 4    금5반
# dtype: object

# %%
data_dic = {
    'year':[2018, 2019, 2020],
    'sales' : [350, 480, 1099]
}
data_dic
# Out:
# {'year': [2018, 2019, 2020], 'sales': [350, 480, 1099]}

# %%
df1 = pd.DataFrame(data_dic)
df1
# Out:
#    year  sales
# 0  2018    350
# 1  2019    480
# 2  2020   1099

# %%
df2 = pd.DataFrame([[89.2, 92.5, 90.8], [92.8, 89.9, 95.2]], index = ['중간고사', '기말고사'], columns = data2[0:3])
df2
# Out:
#         1반    2반    3반
# 중간고사  89.2  92.5  90.8
# 기말고사  92.8  89.9  95.2

# %%
data_df = [['20201101', 'Hong', '90', '95'], ['20201102', 'Kim', '93', '94'], ['20201103', 'Lee', '87', '97']]
df3 = pd.DataFrame(data_df)
df3
# Out:
#           0     1   2   3
# 0  20201101  Hong  90  95
# 1  20201102   Kim  93  94
# 2  20201103   Lee  87  97

# %%
df3.columns = ['학번', '이름', '중간고사', '기말고사']
df3
# Out:
#          학번    이름 중간고사 기말고사
# 0  20201101  Hong   90   95
# 1  20201102   Kim   93   94
# 2  20201103   Lee   87   97

# %%
df3.head(2)
# Out:
#          학번    이름 중간고사 기말고사
# 0  20201101  Hong   90   95
# 1  20201102   Kim   93   94

# %%
df3.tail(2)
# Out:
#          학번   이름 중간고사 기말고사
# 1  20201102  Kim   93   94
# 2  20201103  Lee   87   97

# %%
df3['이름']
# Out:
# 0    Hong
# 1     Kim
# 2     Lee
# Name: 이름, dtype: object

# %%
df3.to_csv('./score.csv')

# %%
df4 = pd.read_csv('score.csv')
df4
# Out:
#    Unnamed: 0        학번    이름  중간고사  기말고사
# 0           0  20201101  Hong    90    95
# 1           1  20201102   Kim    93    94
# 2           2  20201103   Lee    87    97

# %%
df4 = pd.read_csv('score.csv', index_col=0)
df4
# Out:
#          학번    이름  중간고사  기말고사
# 0  20201101  Hong    90    95
# 1  20201102   Kim    93    94
# 2  20201103   Lee    87    97

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([10,20,30,40])

# %%
plt.plot([10,20,30,40])
plt.show()

# %%
plt.plot([1,2,3,4], [10,20,30,40])
plt.show()

# %%
y1 = [350, 410, 520, 695]
y2 = [200, 250, 385, 350]
x = range(len(y1))

# %%
plt.plot([11,12,13,14], [10,20,30,40,50])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-5b1d68d2a6dc> in <module>
# ----> 1 plt.plot([11,12,13,14], [10,20,30,40,50])
#
# /usr/local/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2986 @_copy_docstring_and_deprecators(Axes.plot)
#    2987 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2988     return gca().plot(
#    2989         *args, scalex=scalex, scaley=scaley,
#    2990         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
# ...

# %%
plt.title('graph example')
plt.plot([10,20,30,40], color='r', linestyle='--', label='asc')
plt.plot([40,30,20,10], ls=':', label='desc')
plt.legend(loc=9)
plt.xlabel('index')
plt.ylabel('value')
plt.show()

# %%
plt.title('marker example')
plt.plot([10,20,30,40], 'r.', label='circle') #빨간색 원형 마커
plt.plot([40,30,20,10], 'g^--', label='triangle up')
plt.legend(loc=8) #범례 표시
plt.show()

# %%
y1 = [350, 410, 520, 695]
y2 = [200, 250, 385, 350]
x = range(len(y1)) # y1 길이 범위로 x 리스트인 [0, 1, 2, 3] 형성

# %%
plt.bar(x, y2, color='r')
plt.show()

# %%
plt.bar(x, y1, width=0.7, color='blue')
plt.show()

# %%
plt.bar(x, y1, width=0.7, color='blue')
plt.bar(x, y2, width=0.7, color='red', bottom=y1)
plt.title('Quarterly sales')
plt.xlabel('Quarters') # x축 레이블
plt.ylabel('sales')
xLabel = ['first', 'second', 'third', 'fourth'] # 눈금 이름 리스트 생성
plt.xticks(x, xLabel, fontsize=10) # 바 차트의 x 축 눈금 이름 설정
plt.legend(['chairs', 'desks']) # 범례 설정
plt.show()

# %%
import csv

# %%
f = open('seoul.csv', encoding='euc-kr')
data = csv.reader(f)
for row in data:
    print(row)
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
# ['1907.10.1', '108', '13.5', '7.9', '20.7']
# ['1907.10.2', '108', '16.2', '7.9', '22']
# ['1907.10.3', '108', '16.2', '13.1', '21.3']
# ['1907.10.4', '108', '16.5', '11.2', '22']
# ['1907.10.5', '108', '17.6', '10.9', '25.4']
# ['1907.10.6', '108', '13', '11.2', '21.3']
# ['1907.10.7', '108', '11.3', '6.3', '16.1']
# ['1907.10.8', '108', '8.9', '3.9', '14.9']
# ['1907.10.9', '108', '11.6', '3.8', '21.1']
# ['1907.10.10', '108', '14.2', '6.4', '24.1']
# ['1907.10.11', '108', '15.4', '10.1', '20.4']
# ['1907.10.12', '108', '13.9', '11.1', '17.4']
# ['1907.10.13', '108', '13.8', '8.3', '21.3']
# ['1907.10.14', '108', '13', '6.1', '20.6']
# ['1907.10.15', '108', '13.1', '5.7', '20.9']
# ['1907.10.16', '108', '14.1', '8.2', '20.2']
# ['1907.10.17', '108', '16.4', '10.3', '21.6']
# ['1907.10.18', '108', '14.3', '9.8', '20.9']
# ['1907.10.19', '108', '13.9', '6.7', '21.3']
# ['1907.10.20', '108', '18.3', '12.4', '22.7']
# ...

# %%
f.close()

# %%
print(row)
# Out:
# ['2019.1.17', '108', '-0.3', '-3.2', '4']

# %%
f = open('seoul.csv', encoding='euc-kr')
data = csv.reader(f)
next(data)
result = []
for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))
print(result)
f.close()
# Out:
# [20.7, 22.0, 21.3, 22.0, 25.4, 21.3, 16.1, 14.9, 21.1, 24.1, 20.4, 17.4, 21.3, 20.6, 20.9, 20.2, 21.6, 20.9, 21.3, 22.7, 19.9, 19.6, 16.3, 17.1, 18.7, 18.2, 20.7, 19.6, 20.0, 20.1, 20.3, 21.3, 21.1, 11.1, 13.6, 17.0, 18.1, 12.4, 9.4, 11.9, 13.2, 13.4, 14.9, 16.4, 15.2, 17.6, 12.6, 11.7, 6.7, 4.3, 7.1, 6.2, 11.2, 9.9, 5.9, -0.7, 1.5, 1.9, 2.0, 2.9, -2.4, 1.4, 3.4, 6.1, 1.3, 2.6, 5.8, 1.9, 6.6, 8.1, 4.3, 0.6, 3.8, 9.0, 6.4, -5.1, -2.4, -2.1, -0.4, -0.2, 1.9, -8.1, -10.2, -9.4, 0.9, 6.8, 6.4, -0.7, -1.9, -4.4, -6.1, -2.1, -1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, 1.6, -0.2, -5.4, -4.1, -5.5, -5.7, -3.7, 1.3, -4.1, -2.5, -2.8, -1.2, 1.3, 2.3, 2.0, -1.4, -1.6, 0.3, 5.5, 7.3, 5.1, 5.4, 2.7, 1.7, 0.8, 4.1, 8.4, 6.3, 5.6, 4.0, 0.1, 4.9, 4.0, 7.9, 7.9, 2.2, 1.9, 1.5, 1.5, 1.8, 2.6, 3.8, 6.7, 11.8, 13.5, 15.7, 10.7, 7.9, 4.3, 6.0, 12.5, 17.0, 14.7, 11.4, 7.4, 8.0, 15.5
# ...

# %%
plt.plot(result, 'r')
plt.show()

# %%
plt.figure(figsize=(10,2))
plt.plot(result, 'r')
plt.show()

# %%
data = '1907-10-01'
print(data.split('-'))
# Out:
# ['1907', '10', '01']

# %%
print(data.split('-')[0])
print(data.split('-')[1])
print(data.split('-')[2])
# Out:
# 1907
# 10
# 01

# %%
f = open('seoul.csv', encoding='euc-kr')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] != '':
        if row[0].split('.')[1] == '8':
            result.append(float(row[-1]))
plt.plot(result, 'hotpink')
plt.show()

# %%
f = open('seoul.csv', encoding='euc-kr')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        if row[0].split('.')[1] == '4' and row[0].split('.')[2] == '1' :
            result.append(float(row[-1]))
            
plt.plot(result, 'skyblue')
plt.show()

# %%
f = open('seoul.csv', encoding='euc-kr')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data :
    if row[-1] != '' and row[-2] != '' :
        if 1983 <= int(row[0].split('.')[0]) :
            if row[0].split('.')[1] == '4' and row[0].split('.')[2] == '1' :
                high.append(float(row[-1]))
                low.append(float(row[-2]))
                
plt.title('4월 1일의 기온 변화 그래프')
plt.plot(high, 'hotpink')
plt.plot(low, 'skyblue')
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
f = open('seoul.csv', encoding='euc-kr')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data :
    if row[-1] != '' and row[-2] != '' :
        if 1983 <= int(row[0].split('.')[0]) :
            if row[0].split('.')[1] == '4' and row[0].split('.')[2] == '1' :
                high.append(float(row[-1]))
                low.append(float(row[-2]))
                
plt.rc('font', family='AppleGothic') # 윈도우는 Malgun Gothic 로
plt.title('4월 1일의 기온 변화 그래프')
plt.rcParams['axes.unicode_minus']=False
plt.plot(high, 'hotpink')
plt.plot(low, 'skyblue')
plt.show()

# %%
f = open('seoul.csv', encoding='euc-kr')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data :
    if row[-1] != '' and row[-2] != '' :
        if 1983 <= int(row[0].split('.')[0]) :
            if row[0].split('.')[1] == '2' and row[0].split('.')[2] == '1' :
                high.append(float(row[-1]))
                low.append(float(row[-2]))
                
plt.rc('font', family='AppleGothic') # 윈도우는 Malgun Gothic 로
plt.title('2월 1일의 기온 변화 그래프')
plt.rcParams['axes.unicode_minus']=False
plt.plot(high, 'hotpink', label='high')
plt.plot(low, 'skyblue', label='low')
plt.legend(loc=1)
plt.show()

# %%
plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %%
import random

# %%
print(random.randint(1, 6))
# Out:
# 1

# %%
dice = []
for i in range(5):
    dice.append(random.randint(1, 6))
print(dice)

plt.xlim(1, 6)
plt.hist(dice, bins=6)
plt.show()
# Out:
# [6, 2, 6, 5, 3]

# %%
dice = []
for i in range(100):
    dice.append(random.randint(1, 6))
print(dice)

plt.xlim(1, 6)
plt.hist(dice, bins=6)
plt.show()
# Out:
# [2, 5, 5, 5, 4, 2, 3, 6, 3, 1, 4, 6, 6, 4, 4, 2, 4, 4, 3, 3, 6, 6, 1, 1, 3, 2, 2, 6, 5, 6, 5, 6, 1, 5, 4, 5, 3, 6, 6, 3, 5, 4, 2, 5, 3, 1, 5, 1, 2, 4, 1, 5, 3, 3, 5, 1, 4, 2, 5, 6, 2, 3, 1, 1, 5, 5, 2, 3, 5, 3, 3, 3, 2, 1, 3, 1, 6, 3, 5, 3, 1, 5, 6, 1, 2, 1, 3, 3, 5, 4, 6, 6, 2, 6, 2, 1, 5, 4, 1, 5]

# %%
dice = []
for i in range(1000000):
    dice.append(random.randint(1, 6))
print(dice)

plt.xlim(1, 6)
plt.hist(dice, bins=6)
plt.show()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
f = open('seoul.csv', encoding='euc-kr')
data = csv.reader(f)
next(data)
result = []

for row in data :
    if row[-1] != '' :
        result.append(float(row[-1]))

plt.hist(result, bins = 100, color = 'r')
plt.show()

# %%
f = open('seoul.csv', encoding='euc-kr')
data = csv.reader(f)
next(data)
aug = []

for row in data :
    month = row[0].split('.')[1]
    if row[-1] != '' :
        if month == '8':
            aug.append(float(row[-1]))

plt.hist(aug, bins = 100, color = 'r')
plt.show()

# %%
f = open('seoul.csv', encoding='euc-kr')
data = csv.reader(f)
next(data)
aug = []
jan = []

for row in data :
    month = row[0].split('.')[1]
    if row[-1] != '' :
        if month == '8':
            aug.append(float(row[-1]))
        if month == '1':
            jan.append(float(row[-1]))

plt.hist(aug, bins = 100, color = 'r', label = 'Aug')
plt.hist(jan, bins = 100, color = 'b', label = 'Jan')
plt.legend()
plt.show()

# %%
f = open('incheon.csv', encoding='euc-kr')
data = csv.reader(f)
next(data)
high = []
low = []

for row in data :
    if row[-1] != '' and row[-2] != '' :
        high.append(float(row[-1]))
        low.append(float(row[-2]))
                
plt.figure(figsize=(15 ,5))
plt.title('기온 변화 그래프')
plt.plot(high, 'hotpink')
plt.plot(low, 'skyblue')
plt.show()

# %%
f = open('incheon.csv', encoding='euc-kr')
data = csv.reader(f)
next(data)
aug = []

for row in data :
    year = row[0].split('.')[0]
    if row[-1] != '' :
        if year == '2018':
            aug.append(float(row[-1]))

plt.hist(aug, bins = 100, color = 'r')
plt.show()

# %%
name = ['도', '개', '걸', '윷', '모']
test = []
for i in range(100):
    test.append(name[random.randint(0, 4)])

test.sort(key = lambda x : name.index(x))
plt.hist(test, bins=5)
plt.show()

# %%
name = ['도', '개', '걸', '윷', '모']
test = []
for i in range(1000):
    test.append(name[random.randint(0, 4)])

test.sort(key = lambda x : name.index(x))
plt.hist(test, bins=5)
plt.show()

# %%
name = ['도', '개', '걸', '윷', '모']
test = []
for i in range(10000):
    test.append(name[random.randint(0, 4)])

test.sort(key = lambda x : name.index(x))
plt.hist(test, bins=5)
plt.show()

# %%
name = ['도', '개', '걸', '윷', '모']
test = []
for i in range(100000):
    test.append(name[random.randint(0, 4)])

test.sort(key = lambda x : name.index(x))
plt.hist(test, bins=5)
plt.show()

# %%
name = ['도', '개', '걸', '윷', '모']
test = []
for i in range(1000000):
    test.append(name[random.randint(0, 4)])

test.sort(key = lambda x : name.index(x))
plt.hist(test, bins=5)
plt.show()

# %%
df = pd.read_csv('customer_master.csv')

# %%
df.head()
# Out:
#   customer_id customer_name registration_date                        email  \
# 0    IK152942           김서준   2019-01-01 0:25  hirata_yuujirou@example.com
# 1    TS808488           김예준   2019-01-01 1:13    tamura_shiori@example.com
# 2    AS834628           김도윤   2019-01-01 2:00      hisano_yuki@example.com
# 3    AS345469           김시우   2019-01-01 4:48   tsuruoka_kaoru@example.com
# 4    GD892565           김주원   2019-01-01 4:54   oouchi_takashi@example.com
#
#   gender  age       birth   pref
# 0      M   29  1990-06-10  대전광역시
# 1      F   33  1986-05-20  인천광역시
# 2      F   63  1956-01-02  광주광역시
# 3      M   74  1945-03-25  인천광역시
# 4      M   54  1965-08-05  울산광역시

# %%
df.tail()
# Out:
#      customer_id customer_name registration_date                        email  \
# 4995    AS677229           정우석  2019-07-31 16:52    hirayama_risa@example.com
# 4996    HD758694           정영훈  2019-07-31 19:09  nakahara_mahiru@example.com
# 4997    PL538517           정준기  2019-07-31 19:30      tabata_yuu1@example.com
# 4998    OA955088           정도형  2019-07-31 22:32  setouchi_hikaru@example.com
# 4999    HI349563           정지석  2019-07-31 22:49      horii_kanji@example.com
#
#      gender  age       birth   pref
# 4995      F   77  1941-10-17  대전광역시
# 4996      F   27  1991-11-13  광주광역시
# 4997      F   73  1945-12-28  대전광역시
# 4998      F   75  1944-04-09  부산광역시
# 4999      M   21  1998-02-06  서울특별시

# %%
df = pd.read_csv('item_master.csv')

# %%
df.head()
# Out:
#   item_id item_name  item_price
# 0    S001      PC-A       50000
# 1    S002      PC-B       85000
# 2    S003      PC-C      120000
# 3    S004      PC-D      180000
# 4    S005      PC-E      210000

# %%
df.tail()
# Out:
#   item_id item_name  item_price
# 0    S001      PC-A       50000
# 1    S002      PC-B       85000
# 2    S003      PC-C      120000
# 3    S004      PC-D      180000
# 4    S005      PC-E      210000

# %%
df = pd.read_csv('transaction_1.csv')

# %%
df.head()
# Out:
#   transaction_id   price         payment_date customer_id
# 0    T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1    T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2    T0000000115  120000  2019-02-01 02:34:19    HD298120
# 3    T0000000116  210000  2019-02-01 02:47:23    IK452215
# 4    T0000000117  170000  2019-02-01 04:33:46    PL542865

# %%
df.tail()
# Out:
#      transaction_id   price         payment_date customer_id
# 4995    T0000005108  210000  2019-06-15 02:42:41    HD315748
# 4996    T0000005109  150000  2019-06-15 03:36:16    HI215420
# 4997    T0000005110   50000  2019-06-15 03:44:06    IK880102
# 4998    T0000005111  210000  2019-06-15 04:14:06    IK074758
# 4999    T0000005112   50000  2019-06-15 04:42:38    HD444151

# %%
df = pd.read_csv('transaction_detail_1.csv')

# %%
df.head()
# Out:
#    detail_id transaction_id item_id  quantity
# 0          0    T0000000113    S005         1
# 1          1    T0000000114    S001         1
# 2          2    T0000000115    S003         1
# 3          3    T0000000116    S005         1
# 4          4    T0000000117    S002         2

# %%
df.tail()
# Out:
#       detail_id transaction_id item_id  quantity
# 4995       4995    T0000004865    S003         1
# 4996       4996    T0000004866    S001         3
# 4997       4997    T0000004867    S001         3
# 4998       4998    T0000004868    S005         1
# 4999       4999    T0000004869    S003         1
